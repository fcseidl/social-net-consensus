# %%
# Idk bro. I'm just trying to get this to work.

import numpy as np
import matplotlib.pyplot as plt

a = 3
# plot a histogram of 300 normally distributed random numbers with mean 0 and standard deviation a
x = np.random.normal(0, a, 3000)
y = np.random.normal(0,1,3000)*a
plt.hist(x, bins=20, alpha=0.5)
plt.hist(y, bins=20, alpha=0.5)
plt.show()
